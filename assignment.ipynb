# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
data = pd.read_csv("Peru_2019_AudioMoth_Data_Full.csv")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (1,11,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.shape
# Out:
# (98638, 20)

# %%
data.tail(20)
# Out:
#       AudioMothCode AudioMothID                   SourceFile       Directory  \
# 98618         WWF-5         NaN  GRABADOR-WWF-5/5D313488.WAV  GRABADOR-WWF-5
# 98619         WWF-5         NaN  GRABADOR-WWF-5/5D3136E0.WAV  GRABADOR-WWF-5
# 98620         WWF-5         NaN  GRABADOR-WWF-5/5D313938.WAV  GRABADOR-WWF-5
# 98621         WWF-5         NaN  GRABADOR-WWF-5/5D313B90.WAV  GRABADOR-WWF-5
# 98622         WWF-5         NaN  GRABADOR-WWF-5/5D313DE8.WAV  GRABADOR-WWF-5
# 98623         WWF-5         NaN  GRABADOR-WWF-5/5D314040.WAV  GRABADOR-WWF-5
# 98624         WWF-5         NaN  GRABADOR-WWF-5/5D314298.WAV  GRABADOR-WWF-5
# 98625         WWF-5         NaN  GRABADOR-WWF-5/5D3144F0.WAV  GRABADOR-WWF-5
# 98626         WWF-5         NaN  GRABADOR-WWF-5/5D314748.WAV  GRABADOR-WWF-5
# 98627         WWF-5         NaN  GRABADOR-WWF-5/5D3149A0.WAV  GRABADOR-WWF-5
# 98628         WWF-5         NaN  GRABADOR-WWF-5/5D314BF8.WAV  GRABADOR-WWF-5
# 98629         WWF-5         NaN  GRABADOR-WWF-5/5D314E50.WAV  GRABADOR-WWF-5
# 98630         WWF-5         NaN  GRABADOR-WWF-5/5D3150A8.WAV  GRABADOR-WWF-5
# 98631         WWF-5         NaN  GRABADOR-WWF-5/5D315300.WAV  GRABADOR-WWF-5
# 98632         WWF-5         NaN  GRABADOR-WWF-5/5D315558.WAV  GRABADOR-WWF-5
# 98633         WWF-5         NaN  GRABADOR-WWF-5/5D3157B0.WAV  GRABADOR-WWF-5
# 98634         WWF-5         NaN  GRABADOR-WWF-5/5D315A08.WAV  GRABADOR-WWF-5
# 98635         WWF-5         NaN  GRABADOR-WWF-5/5D315C60.WAV  GRABADOR-WWF-5
# 98636         WWF-5         NaN  GRABADOR-WWF-5/5D315EB8.WAV  GRABADOR-WWF-5
# 98637         WWF-5         NaN  GRABADOR-WWF-5/5D316110.WAV  GRABADOR-WWF-5
#
#            FileName  FileSize  Encoding  NumChannels  SampleRate  \
# 98618  5D313488.WAV         0       NaN          NaN         NaN
# 98619  5D3136E0.WAV         0       NaN          NaN         NaN
# 98620  5D313938.WAV         0       NaN          NaN         NaN
# 98621  5D313B90.WAV         0       NaN          NaN         NaN
# 98622  5D313DE8.WAV         0       NaN          NaN         NaN
# 98623  5D314040.WAV         0       NaN          NaN         NaN
# 98624  5D314298.WAV         0       NaN          NaN         NaN
# 98625  5D3144F0.WAV         0       NaN          NaN         NaN
# 98626  5D314748.WAV         0       NaN          NaN         NaN
# 98627  5D3149A0.WAV         0       NaN          NaN         NaN
# 98628  5D314BF8.WAV         0       NaN          NaN         NaN
# 98629  5D314E50.WAV         0       NaN          NaN         NaN
# 98630  5D3150A8.WAV         0       NaN          NaN         NaN
# 98631  5D315300.WAV         0       NaN          NaN         NaN
# 98632  5D315558.WAV         0       NaN          NaN         NaN
# 98633  5D3157B0.WAV         0       NaN          NaN         NaN
# 98634  5D315A08.WAV         0       NaN          NaN         NaN
# 98635  5D315C60.WAV         0       NaN          NaN         NaN
# 98636  5D315EB8.WAV         0       NaN          NaN         NaN
# 98637  5D316110.WAV         0       NaN          NaN         NaN
#
#        AvgBytesPerSec  BitsPerSample StartDateTime  Duration          Error  \
# 98618             NaN            NaN           NaN       NaN  File is empty
# 98619             NaN            NaN           NaN       NaN  File is empty
# 98620             NaN            NaN           NaN       NaN  File is empty
# 98621             NaN            NaN           NaN       NaN  File is empty
# 98622             NaN            NaN           NaN       NaN  File is empty
# 98623             NaN            NaN           NaN       NaN  File is empty
# 98624             NaN            NaN           NaN       NaN  File is empty
# 98625             NaN            NaN           NaN       NaN  File is empty
# 98626             NaN            NaN           NaN       NaN  File is empty
# 98627             NaN            NaN           NaN       NaN  File is empty
# 98628             NaN            NaN           NaN       NaN  File is empty
# 98629             NaN            NaN           NaN       NaN  File is empty
# 98630             NaN            NaN           NaN       NaN  File is empty
# 98631             NaN            NaN           NaN       NaN  File is empty
# 98632             NaN            NaN           NaN       NaN  File is empty
# 98633             NaN            NaN           NaN       NaN  File is empty
# 98634             NaN            NaN           NaN       NaN  File is empty
# 98635             NaN            NaN           NaN       NaN  File is empty
# 98636             NaN            NaN           NaN       NaN  File is empty
# 98637             NaN            NaN           NaN       NaN  File is empty
#
#       Comment Artist             FileCreateDate FileType FileTypeExtension  \
# 98618     NaN    NaN  2019:12:07 15:29:10-08:00      NaN               NaN
# 98619     NaN    NaN  2019:12:07 19:06:53-08:00      NaN               NaN
# 98620     NaN    NaN  2019:12:07 15:29:10-08:00      NaN               NaN
# 98621     NaN    NaN  2019:12:07 18:45:59-08:00      NaN               NaN
# 98622     NaN    NaN  2019:12:07 18:45:59-08:00      NaN               NaN
# 98623     NaN    NaN  2019:12:07 15:29:10-08:00      NaN               NaN
# 98624     NaN    NaN  2019:12:07 15:29:10-08:00      NaN               NaN
# 98625     NaN    NaN  2019:12:07 19:06:53-08:00      NaN               NaN
# 98626     NaN    NaN  2019:12:07 15:29:10-08:00      NaN               NaN
# 98627     NaN    NaN  2019:12:07 19:06:53-08:00      NaN               NaN
# 98628     NaN    NaN  2019:12:07 18:45:59-08:00      NaN               NaN
# 98629     NaN    NaN  2019:12:07 18:45:59-08:00      NaN               NaN
# 98630     NaN    NaN  2019:12:07 19:06:53-08:00      NaN               NaN
# 98631     NaN    NaN  2019:12:07 15:29:10-08:00      NaN               NaN
# 98632     NaN    NaN  2019:12:07 15:29:10-08:00      NaN               NaN
# 98633     NaN    NaN  2019:12:07 19:06:53-08:00      NaN               NaN
# 98634     NaN    NaN  2019:12:07 18:45:59-08:00      NaN               NaN
# 98635     NaN    NaN  2019:12:07 18:45:59-08:00      NaN               NaN
# 98636     NaN    NaN  2019:12:07 18:45:59-08:00      NaN               NaN
# 98637     NaN    NaN  2019:12:07 15:29:10-08:00      NaN               NaN
#
#       MIMEType
# 98618      NaN
# 98619      NaN
# 98620      NaN
# 98621      NaN
# 98622      NaN
# 98623      NaN
# 98624      NaN
# 98625      NaN
# 98626      NaN
# 98627      NaN
# 98628      NaN
# 98629      NaN
# 98630      NaN
# 98631      NaN
# 98632      NaN
# 98633      NaN
# 98634      NaN
# 98635      NaN
# 98636      NaN
# 98637      NaN

# %%
unique_moth_id = data['AudioMothCode'].unique()
print(unique_moth_id)
# Out:
# ['AM-1' 'AM-10' 'AM-11' 'AM-12' 'AM-13' 'AM-14' 'AM-15' 'AM-16' 'AM-17'
#  'AM-18' 'AM-2' 'AM-20' 'AM-22' 'AM-23' 'AM-24' 'AM-25' 'AM-26' 'AM-27'
#  'AM-29' 'AM-3' 'AM-30' 'AM-4' 'AM-5' 'AM-6' 'AM-7' 'AM-8' 'AM-9' 'WWF-1'
#  'WWF-2' 'WWF-3' 'WWF-4' 'WWF-5']

# %%
data = pd.read_csv("Peru_2019_AudioMoth_Data_Full.csv")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (1,11,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data = data[data['Error'].isna()]
data1 = data[~data['AudioMothCode'].isin(['AM-8','AM-19','AM-21','AM-28'])]
data1 = data1[(data1['Duration'] >= 60.00) & (data1['Duration'] < 61.00)]
data1 = data1[(data1['FileSize'].notna()) & (data1['FileSize'] > 46 * 10 ** 6)]
# data1['date_time'] = pd.to_datetime(data1['StartDateTime'])  #Doesnt work because some StartDateTime is incorrect
data1['date_time'] = data1['Comment'].apply(lambda x: datetime.strptime(' '.join(x.split()[2:4]),'%H:%M:%S %d/%m/%Y'))
# data1.tail(20)
data1['hour'] = data1['date_time'].dt.hour

# %%
data1.shape
# Out:
# (90981, 21)

# %%
data1.tail(20)
# Out:
#       AudioMothCode AudioMothID                   SourceFile       Directory  \
# 98471         WWF-5         NaN  GRABADOR-WWF-5/5D2F9A60.WAV  GRABADOR-WWF-5
# 98472         WWF-5         NaN  GRABADOR-WWF-5/5D2F9CB8.WAV  GRABADOR-WWF-5
# 98473         WWF-5         NaN  GRABADOR-WWF-5/5D2F9F10.WAV  GRABADOR-WWF-5
# 98474         WWF-5         NaN  GRABADOR-WWF-5/5D2FA168.WAV  GRABADOR-WWF-5
# 98475         WWF-5         NaN  GRABADOR-WWF-5/5D2FA3C0.WAV  GRABADOR-WWF-5
# 98477         WWF-5         NaN  GRABADOR-WWF-5/5D2FA870.WAV  GRABADOR-WWF-5
# 98478         WWF-5         NaN  GRABADOR-WWF-5/5D2FAAC8.WAV  GRABADOR-WWF-5
# 98479         WWF-5         NaN  GRABADOR-WWF-5/5D2FAD20.WAV  GRABADOR-WWF-5
# 98480         WWF-5         NaN  GRABADOR-WWF-5/5D2FAF78.WAV  GRABADOR-WWF-5
# 98481         WWF-5         NaN  GRABADOR-WWF-5/5D2FB1D0.WAV  GRABADOR-WWF-5
# 98483         WWF-5         NaN  GRABADOR-WWF-5/5D2FB680.WAV  GRABADOR-WWF-5
# 98484         WWF-5         NaN  GRABADOR-WWF-5/5D2FB8D8.WAV  GRABADOR-WWF-5
# 98486         WWF-5         NaN  GRABADOR-WWF-5/5D2FBD88.WAV  GRABADOR-WWF-5
# 98487         WWF-5         NaN  GRABADOR-WWF-5/5D2FBFE0.WAV  GRABADOR-WWF-5
# 98488         WWF-5         NaN  GRABADOR-WWF-5/5D2FC238.WAV  GRABADOR-WWF-5
# 98489         WWF-5         NaN  GRABADOR-WWF-5/5D2FC490.WAV  GRABADOR-WWF-5
# 98492         WWF-5         NaN  GRABADOR-WWF-5/5D2FCB98.WAV  GRABADOR-WWF-5
# 98493         WWF-5         NaN  GRABADOR-WWF-5/5D2FCDF0.WAV  GRABADOR-WWF-5
# 98497         WWF-5         NaN  GRABADOR-WWF-5/5D2FD750.WAV  GRABADOR-WWF-5
# 98511         WWF-5         NaN  GRABADOR-WWF-5/5D2FF820.WAV  GRABADOR-WWF-5
#
#            FileName  FileSize  Encoding  NumChannels  SampleRate  \
# 98471  5D2F9A60.WAV  46080192       1.0          1.0    384000.0
# 98472  5D2F9CB8.WAV  46080192       1.0          1.0    384000.0
# 98473  5D2F9F10.WAV  46080192       1.0          1.0    384000.0
# 98474  5D2FA168.WAV  46080192       1.0          1.0    384000.0
# 98475  5D2FA3C0.WAV  46080192       1.0          1.0    384000.0
# 98477  5D2FA870.WAV  46080192       1.0          1.0    384000.0
# 98478  5D2FAAC8.WAV  46080192       1.0          1.0    384000.0
# 98479  5D2FAD20.WAV  46080192       1.0          1.0    384000.0
# 98480  5D2FAF78.WAV  46080192       1.0          1.0    384000.0
# 98481  5D2FB1D0.WAV  46080192       1.0          1.0    384000.0
# 98483  5D2FB680.WAV  46080192       1.0          1.0    384000.0
# 98484  5D2FB8D8.WAV  46080192       1.0          1.0    384000.0
# 98486  5D2FBD88.WAV  46080192       1.0          1.0    384000.0
# 98487  5D2FBFE0.WAV  46080192       1.0          1.0    384000.0
# 98488  5D2FC238.WAV  46080192       1.0          1.0    384000.0
# 98489  5D2FC490.WAV  46080192       1.0          1.0    384000.0
# 98492  5D2FCB98.WAV  46080192       1.0          1.0    384000.0
# 98493  5D2FCDF0.WAV  46080192       1.0          1.0    384000.0
# 98497  5D2FD750.WAV  46080192       1.0          1.0    384000.0
# 98511  5D2FF820.WAV  46080192       1.0          1.0    384000.0
#
#        AvgBytesPerSec  ...  Duration Error  \
# 98471        768000.0  ...  60.00025   NaN
# 98472        768000.0  ...  60.00025   NaN
# 98473        768000.0  ...  60.00025   NaN
# 98474        768000.0  ...  60.00025   NaN
# 98475        768000.0  ...  60.00025   NaN
# 98477        768000.0  ...  60.00025   NaN
# 98478        768000.0  ...  60.00025   NaN
# 98479        768000.0  ...  60.00025   NaN
# 98480        768000.0  ...  60.00025   NaN
# 98481        768000.0  ...  60.00025   NaN
# 98483        768000.0  ...  60.00025   NaN
# 98484        768000.0  ...  60.00025   NaN
# 98486        768000.0  ...  60.00025   NaN
# 98487        768000.0  ...  60.00025   NaN
# 98488        768000.0  ...  60.00025   NaN
# 98489        768000.0  ...  60.00025   NaN
# 98492        768000.0  ...  60.00025   NaN
# 98493        768000.0  ...  60.00025   NaN
# 98497        768000.0  ...  60.00025   NaN
# 98511        768000.0  ...  60.00025   NaN
#
#                                                  Comment Artist  \
# 98471  Recorded at 22:00:00 17/07/2019 (UTC) by Audio...    NaN
# 98472  Recorded at 22:10:00 17/07/2019 (UTC) by Audio...    NaN
# 98473  Recorded at 22:20:00 17/07/2019 (UTC) by Audio...    NaN
# 98474  Recorded at 22:30:00 17/07/2019 (UTC) by Audio...    NaN
# 98475  Recorded at 22:40:00 17/07/2019 (UTC) by Audio...    NaN
# 98477  Recorded at 23:00:00 17/07/2019 (UTC) by Audio...    NaN
# 98478  Recorded at 23:10:00 17/07/2019 (UTC) by Audio...    NaN
# 98479  Recorded at 23:20:00 17/07/2019 (UTC) by Audio...    NaN
# 98480  Recorded at 23:30:00 17/07/2019 (UTC) by Audio...    NaN
# 98481  Recorded at 23:40:00 17/07/2019 (UTC) by Audio...    NaN
# 98483  Recorded at 00:00:00 18/07/2019 (UTC) by Audio...    NaN
# 98484  Recorded at 00:10:00 18/07/2019 (UTC) by Audio...    NaN
# 98486  Recorded at 00:30:00 18/07/2019 (UTC) by Audio...    NaN
# 98487  Recorded at 00:40:00 18/07/2019 (UTC) by Audio...    NaN
# 98488  Recorded at 00:50:00 18/07/2019 (UTC) by Audio...    NaN
# 98489  Recorded at 01:00:00 18/07/2019 (UTC) by Audio...    NaN
# 98492  Recorded at 01:30:00 18/07/2019 (UTC) by Audio...    NaN
# 98493  Recorded at 01:40:00 18/07/2019 (UTC) by Audio...    NaN
# 98497  Recorded at 02:20:00 18/07/2019 (UTC) by Audio...    NaN
# 98511  Recorded at 04:40:00 18/07/2019 (UTC) by Audio...    NaN
#
#                   FileCreateDate FileType FileTypeExtension     MIMEType  \
# 98471  2019:12:07 17:14:33-08:00      WAV               WAV  audio/x-wav
# 98472  2019:12:07 17:14:39-08:00      WAV               WAV  audio/x-wav
# 98473  2019:12:07 17:14:44-08:00      WAV               WAV  audio/x-wav
# 98474  2019:12:07 17:18:36-08:00      WAV               WAV  audio/x-wav
# 98475  2019:12:07 17:18:31-08:00      WAV               WAV  audio/x-wav
# 98477  2019:12:07 17:18:41-08:00      WAV               WAV  audio/x-wav
# 98478  2019:12:07 17:18:46-08:00      WAV               WAV  audio/x-wav
# 98479  2019:12:07 17:18:52-08:00      WAV               WAV  audio/x-wav
# 98480  2019:12:07 17:18:57-08:00      WAV               WAV  audio/x-wav
# 98481  2019:12:07 17:19:02-08:00      WAV               WAV  audio/x-wav
# 98483  2019:12:07 17:19:12-08:00      WAV               WAV  audio/x-wav
# 98484  2019:12:07 17:19:07-08:00      WAV               WAV  audio/x-wav
# 98486  2019:12:07 17:19:18-08:00      WAV               WAV  audio/x-wav
# 98487  2019:12:07 17:19:23-08:00      WAV               WAV  audio/x-wav
# 98488  2019:12:07 17:19:28-08:00      WAV               WAV  audio/x-wav
# 98489  2019:12:07 17:19:33-08:00      WAV               WAV  audio/x-wav
# 98492  2019:12:07 17:19:38-08:00      WAV               WAV  audio/x-wav
# 98493  2019:12:07 17:19:43-08:00      WAV               WAV  audio/x-wav
# 98497  2019:12:07 17:19:49-08:00      WAV               WAV  audio/x-wav
# 98511  2019:12:07 17:19:54-08:00      WAV               WAV  audio/x-wav
#
#                 date_time hour
# 98471 2019-07-17 22:00:00   22
# 98472 2019-07-17 22:10:00   22
# 98473 2019-07-17 22:20:00   22
# 98474 2019-07-17 22:30:00   22
# 98475 2019-07-17 22:40:00   22
# 98477 2019-07-17 23:00:00   23
# 98478 2019-07-17 23:10:00   23
# 98479 2019-07-17 23:20:00   23
# 98480 2019-07-17 23:30:00   23
# 98481 2019-07-17 23:40:00   23
# 98483 2019-07-18 00:00:00    0
# 98484 2019-07-18 00:10:00    0
# 98486 2019-07-18 00:30:00    0
# 98487 2019-07-18 00:40:00    0
# 98488 2019-07-18 00:50:00    0
# 98489 2019-07-18 01:00:00    1
# 98492 2019-07-18 01:30:00    1
# 98493 2019-07-18 01:40:00    1
# 98497 2019-07-18 02:20:00    2
# 98511 2019-07-18 04:40:00    4
#
# [20 rows x 22 columns]

# %%
grouped = data1.groupby('AudioMothCode')
req = grouped.filter(lambda x: len(x) >= 24)

# %%
req.shape
# Out:
# (90973, 22)

# %%
req.tail(10)
# Out:
#       AudioMothCode AudioMothID                   SourceFile       Directory  \
# 98483         WWF-5         NaN  GRABADOR-WWF-5/5D2FB680.WAV  GRABADOR-WWF-5
# 98484         WWF-5         NaN  GRABADOR-WWF-5/5D2FB8D8.WAV  GRABADOR-WWF-5
# 98486         WWF-5         NaN  GRABADOR-WWF-5/5D2FBD88.WAV  GRABADOR-WWF-5
# 98487         WWF-5         NaN  GRABADOR-WWF-5/5D2FBFE0.WAV  GRABADOR-WWF-5
# 98488         WWF-5         NaN  GRABADOR-WWF-5/5D2FC238.WAV  GRABADOR-WWF-5
# 98489         WWF-5         NaN  GRABADOR-WWF-5/5D2FC490.WAV  GRABADOR-WWF-5
# 98492         WWF-5         NaN  GRABADOR-WWF-5/5D2FCB98.WAV  GRABADOR-WWF-5
# 98493         WWF-5         NaN  GRABADOR-WWF-5/5D2FCDF0.WAV  GRABADOR-WWF-5
# 98497         WWF-5         NaN  GRABADOR-WWF-5/5D2FD750.WAV  GRABADOR-WWF-5
# 98511         WWF-5         NaN  GRABADOR-WWF-5/5D2FF820.WAV  GRABADOR-WWF-5
#
#            FileName  FileSize  Encoding  NumChannels  SampleRate  \
# 98483  5D2FB680.WAV  46080192       1.0          1.0    384000.0
# 98484  5D2FB8D8.WAV  46080192       1.0          1.0    384000.0
# 98486  5D2FBD88.WAV  46080192       1.0          1.0    384000.0
# 98487  5D2FBFE0.WAV  46080192       1.0          1.0    384000.0
# 98488  5D2FC238.WAV  46080192       1.0          1.0    384000.0
# 98489  5D2FC490.WAV  46080192       1.0          1.0    384000.0
# 98492  5D2FCB98.WAV  46080192       1.0          1.0    384000.0
# 98493  5D2FCDF0.WAV  46080192       1.0          1.0    384000.0
# 98497  5D2FD750.WAV  46080192       1.0          1.0    384000.0
# 98511  5D2FF820.WAV  46080192       1.0          1.0    384000.0
#
#        AvgBytesPerSec  ...  Duration Error  \
# 98483        768000.0  ...  60.00025   NaN
# 98484        768000.0  ...  60.00025   NaN
# 98486        768000.0  ...  60.00025   NaN
# 98487        768000.0  ...  60.00025   NaN
# 98488        768000.0  ...  60.00025   NaN
# 98489        768000.0  ...  60.00025   NaN
# 98492        768000.0  ...  60.00025   NaN
# 98493        768000.0  ...  60.00025   NaN
# 98497        768000.0  ...  60.00025   NaN
# 98511        768000.0  ...  60.00025   NaN
#
#                                                  Comment Artist  \
# 98483  Recorded at 00:00:00 18/07/2019 (UTC) by Audio...    NaN
# 98484  Recorded at 00:10:00 18/07/2019 (UTC) by Audio...    NaN
# 98486  Recorded at 00:30:00 18/07/2019 (UTC) by Audio...    NaN
# 98487  Recorded at 00:40:00 18/07/2019 (UTC) by Audio...    NaN
# 98488  Recorded at 00:50:00 18/07/2019 (UTC) by Audio...    NaN
# 98489  Recorded at 01:00:00 18/07/2019 (UTC) by Audio...    NaN
# 98492  Recorded at 01:30:00 18/07/2019 (UTC) by Audio...    NaN
# 98493  Recorded at 01:40:00 18/07/2019 (UTC) by Audio...    NaN
# 98497  Recorded at 02:20:00 18/07/2019 (UTC) by Audio...    NaN
# 98511  Recorded at 04:40:00 18/07/2019 (UTC) by Audio...    NaN
#
#                   FileCreateDate FileType FileTypeExtension     MIMEType  \
# 98483  2019:12:07 17:19:12-08:00      WAV               WAV  audio/x-wav
# 98484  2019:12:07 17:19:07-08:00      WAV               WAV  audio/x-wav
# 98486  2019:12:07 17:19:18-08:00      WAV               WAV  audio/x-wav
# 98487  2019:12:07 17:19:23-08:00      WAV               WAV  audio/x-wav
# 98488  2019:12:07 17:19:28-08:00      WAV               WAV  audio/x-wav
# 98489  2019:12:07 17:19:33-08:00      WAV               WAV  audio/x-wav
# 98492  2019:12:07 17:19:38-08:00      WAV               WAV  audio/x-wav
# 98493  2019:12:07 17:19:43-08:00      WAV               WAV  audio/x-wav
# 98497  2019:12:07 17:19:49-08:00      WAV               WAV  audio/x-wav
# 98511  2019:12:07 17:19:54-08:00      WAV               WAV  audio/x-wav
#
#                 date_time hour
# 98483 2019-07-18 00:00:00    0
# 98484 2019-07-18 00:10:00    0
# 98486 2019-07-18 00:30:00    0
# 98487 2019-07-18 00:40:00    0
# 98488 2019-07-18 00:50:00    0
# 98489 2019-07-18 01:00:00    1
# 98492 2019-07-18 01:30:00    1
# 98493 2019-07-18 01:40:00    1
# 98497 2019-07-18 02:20:00    2
# 98511 2019-07-18 04:40:00    4
#
# [10 rows x 22 columns]

# %%
print(req['AudioMothCode'].unique())
req['Stratify'] = req['AudioMothCode'] + ", " + str(req['hour'])
# Out:
# ['AM-1' 'AM-10' 'AM-11' 'AM-12' 'AM-13' 'AM-14' 'AM-15' 'AM-16' 'AM-17'
#  'AM-2' 'AM-20' 'AM-22' 'AM-23' 'AM-24' 'AM-25' 'AM-26' 'AM-27' 'AM-29'
#  'AM-3' 'AM-30' 'AM-4' 'AM-5' 'AM-6' 'AM-7' 'AM-9' 'WWF-1' 'WWF-2' 'WWF-3'
#  'WWF-4' 'WWF-5']

# %%
final = data1.groupby(['AudioMothCode','hour']).apply(lambda x: x.sample(1))

# %%
final.shape
# Out:
# (722, 22)

# %%
def stratified_random_sampling(file_path):
    original_data = pd.read_csv(file_path)
    #Dropping rows which have error
    data = original_data[original_data['Error'].isna()]
    
    #Dropping the audio moth codes of the specified values
    data = data[~data['AudioMothCode'].isin(['AM-8','AM-19','AM-21','AM-28'])]
    
    #Choosing only minute long recordings
    data = data[(data['Duration'] >= 60.00) & (data['Duration'] < 61.00)]
    
    #Fltering on file size (gt 46 MB)
    data = data[(data['FileSize'].notna()) & (data['FileSize'] > 46 * 10 ** 6)]
    
    #The StartDateTime previously that I used contained some NA values for some rows of WWF
    data['date_time'] = data['Comment'].apply(lambda x: datetime.strptime(' '.join(x.split()[2:4]),'%H:%M:%S %d/%m/%Y'))

    data['hour'] = data['date_time'].dt.hour
    
    #Removing such rows where we dont have enough samples for an 'AudioMothCode'
    final = data.groupby(['AudioMothCode','hour'], group_keys=False).apply(lambda x: x.sample(1))
    grouped = final.groupby('AudioMothCode')
    final = grouped.filter(lambda x: len(x) >= 24)
    
    #After the preprocessing steps we save this to csv file
    if(final.size > 0):
        final.to_csv('ST_random_samples.csv', index=False)
        return True

    return False
    
 
file_creation = stratified_random_sampling('Peru_2019_AudioMoth_Data_Full.csv')
print(file_creation)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-75-933eb554c952> in <module>
#      31
#      32
# ---> 33 file_creation = stratified_random_sampling('Peru_2019_AudioMoth_Data_Full.csv')
#      34 print(file_creation)
#
# <ipython-input-75-933eb554c952> in stratified_random_sampling(file_path)
#       1 def stratified_random_sampling(file_path):
# ----> 2     original_data = pd.read_csv(file_path)
#       3     #Dropping rows which have error
#       4     data = original_data[original_data['Error'].isna()]
#       5
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Peru_2019_AudioMoth_Data_Full.csv'

# %%
file_creation = stratified_random_sampling('Peru_2019_AudioMoth_Data_Full.csv')
print(file_creation)
# Out:
# True
